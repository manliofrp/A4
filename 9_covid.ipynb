# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from IPython.display import display,HTML
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Leo mi archivo.csv
Covid = pd.read_csv("COVID19Mexico.csv")
#Filtro por filas
Covid= Covid.iloc[0:100000,: ]
Covid
# Out:
# C:\Users\manli\AppData\Local\Temp\ipykernel_16380\445928318.py:2: DtypeWarning:
#
# Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#           ID FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0          0          27/08/2022      1a4a8d       1    12.0        23.0
# 1          1          27/08/2022      01e27d       2     9.0        25.0
# 2          2          27/08/2022      13cf10       2     9.0         9.0
# 3          3          27/08/2022      13c92b       2    12.0         9.0
# 4          4          27/08/2022      04af5f       2    12.0         9.0
# ...      ...                 ...         ...     ...     ...         ...
# 99995  99995          27/08/2022      47548a       2    12.0         9.0
# 99996  99996          27/08/2022      5c2773       2     NaN         9.0
# 99997  99997          27/08/2022      aceb1f       2     4.0         NaN
# 99998  99998          27/08/2022      db2a23       2     4.0         9.0
# 99999  99999          27/08/2022      a88222       2     4.0         9.0
#
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 0       2.0           27           23            8.0  ...        2.0
# 1       2.0           25           25            1.0  ...        2.0
# 2       1.0            9            9           14.0  ...        2.0
# 3       1.0            9            9            2.0  ...        1.0
# 4       1.0            9            9            7.0  ...        1.0
# ...     ...          ...          ...            ...  ...        ...
# 99995   1.0           11           15           31.0  ...        2.0
# 99996   2.0           15           15           95.0  ...        1.0
# 99997   2.0           28           28           22.0  ...        1.0
# 99998   1.0           15            9            6.0  ...        1.0
# 99999   1.0            9            9            7.0  ...        2.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# 0                    2            97                     1
# 1                    2            97                     1
# 2                    1             1                     2
# 3                    2            97                     1
# 4                    2            97                     1
# ...                ...           ...                   ...
# 99995                1             2                     1
# 99996                2            97                     1
# 99997                2            97                     1
# 99998                2            97                     1
# 99999                2            97                     1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                     2.0                    7        99             México
# 1                     2.0                    7        99             México
# 2                    97.0                    3        99             México
# 3                     2.0                    7        99             México
# 4                     2.0                    7        99             México
# ...                   ...                  ...       ...                ...
# 99995                 2.0                    7        99             México
# 99996                 2.0                    7        99             México
# 99997                 1.0                    3        99             México
# 99998                 1.0                    3        99             México
# 99999                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 0               97   97
# 1               97   97
# 2               97   97
# 3               97   97
# 4               97   97
# ...            ...  ...
# 99995           97   97
# 99996           97   97
# 99997           97   97
# 99998           97   97
# 99999           97   97
#
# [100000 rows x 41 columns]

# %%
valores_nulos=Covid.isnull().sum()
valores_nulos
# Out:
# ID                       0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   1
# ENTIDAD_UM               1
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     3
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# RESULTADO_ANTIGENO       1
# CLASIFICACION_FINAL      0
# MIGRANTE                 0
# PAIS_NACIONALIDAD        2
# PAIS_ORIGEN              0
# UCI                      0
# dtype: int64

# %%
#Realizamos una copia del dataframe
covid1=Covid.copy()

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
covid1["EDAD"] =covid1["EDAD"].fillna(method="bfill") 
covid1

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
covid1["EMBARAZO"] =covid1["EMBARAZO"].fillna(method="bfill") 
covid1

# %%
#Sustituir valores nulos con promedio o media
covid1["SECTOR"]=covid1["SECTOR"].fillna(round(covid1["SECTOR"].mean(),1))
covid1

# %%
#Sustituir valores nulos con promedio o media
covid1["SEXO"]=covid1["SEXO"].fillna(round(covid1["SEXO"].mean(),1))
covid1

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
covid1["ENTIDAD_UM"] =covid1["ENTIDAD_UM"].fillna(method="ffill") 
covid1

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
covid1["MUNICIPIO_RES"] =covid1["MUNICIPIO_RES"].fillna(method="ffill") 
covid1

# %%
#Sustituir valores nulos por un string en  concreto 
#Filtro por columnas
covid1["PAIS_NACIONALIDAD"] =covid1["PAIS_NACIONALIDAD"].fillna("México") 
covid1

# %%
#Corroboramos valores nulos
valores_nulos=covid1.isnull().sum()
valores_nulos

# %%
#Realizamos histograma de variables cuantitativas
plt.hist(x=covid1["NEUMONIA"], color='blue', rwidth=0.50)
plt.title('Histograma de Neumonia')
plt.xlabel('Neumonia')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma
